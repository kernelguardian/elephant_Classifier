# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 38A1-28A1
#
#  Directory of C:\Users\Asish\Desktop\course-v3-master\Elephant
#
# 02/06/2020  12:24 AM    <DIR>          .
# 02/06/2020  12:24 AM    <DIR>          ..
# 02/05/2020  11:33 PM    <DIR>          .ipynb_checkpoints
# 02/06/2020  12:22 AM    <DIR>          dwn
# 02/06/2020  12:24 AM           620,656 elephant.ipynb
# 02/06/2020  12:03 AM            27,859 file.txt
# 02/06/2020  12:16 AM    <DIR>          images
#                2 File(s)        648,515 bytes
#                5 Dir(s)  455,189,172,224 bytes free

# %%
# download_images('file.txt', 'dwn', max_pics=200,max_workers=1)

# %%
tfms = get_transforms(do_flip=False)

# %%
data = ImageDataBunch.from_folder('images',bs=38, ds_tfms=tfms, size=224)

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
learner = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learner.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.931333</td>
#       <td>0.066264</td>
#       <td>0.023529</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.571839</td>
#       <td>0.023916</td>
#       <td>0.011765</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.381321</td>
#       <td>0.017104</td>
#       <td>0.011765</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.282965</td>
#       <td>0.008341</td>
#       <td>0.000000</td>
#       <td>00:19</td>
#     </tr>
#   </tbody>
# </table>

# %%
learner.save('stage-1')

# %%
learner.unfreeze()

# %%
learner.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learner.recorder.plot()

# %%
learner.export()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))

# %%
learn.save('stage-2')

# %%
# !dir
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 38A1-28A1
#
#  Directory of C:\Users\Asish\Desktop\course-v3-master\Elephant
#
# 02/06/2020  12:28 AM    <DIR>          .
# 02/06/2020  12:28 AM    <DIR>          ..
# 02/05/2020  11:33 PM    <DIR>          .ipynb_checkpoints
# 02/06/2020  12:22 AM    <DIR>          dwn
# 02/06/2020  12:28 AM           591,539 elephant.ipynb
# 02/06/2020  12:27 AM        87,392,272 export.pkl
# 02/06/2020  12:03 AM            27,859 file.txt
# 02/06/2020  12:27 AM    <DIR>          images
#                3 File(s)     88,011,670 bytes
#                5 Dir(s)  452,076,978,176 bytes free

# %%
learn = load_learner('model')

# %%
learn.predict('sample.jpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-010f3fac51ba> in <module>
# ----> 1 learn.predict('sample.jpg')
#
# c:\users\asish\appdata\local\programs\python\python37\lib\site-packages\fastai\basic_train.py in predict(self, item, return_x, batch_first, with_dropout, **kwargs)
#     368     def predict(self, item:ItemBase, return_x:bool=False, batch_first:bool=True, with_dropout:bool=False, **kwargs):
#     369         "Return predicted class, label and probabilities for `item`."
# --> 370         batch = self.data.one_item(item)
#     371         res = self.pred_batch(batch=batch, with_dropout=with_dropout)
#     372         raw_pred,x = grab_idx(res,0,batch_first=batch_first),batch[0]
#
# c:\users\asish\appdata\local\programs\python\python37\lib\site-packages\fastai\basic_data.py in one_item(self, item, detach, denorm, cpu)
#     179         ds = self.single_ds
#     180         with ds.set_item(item):
# --> 181             return self.one_batch(ds_type=DatasetType.Single, detach=detach, denorm=denorm, cpu=cpu)
#     182
#     183     def show_batch(self, rows:int=5, ds_type:DatasetType=DatasetType.Train, reverse:bool=False, **kwargs)->None:
#
# c:\users\asish\appdata\local\programs\python\python37\lib\site-packages\fastai\basic_data.py in one_batch(self, ds_type, detach, denorm, cpu)
#     166         w = dl.num_workers
#     167         dl.num_workers = 0
# --> 168         try:     x,y = next(iter(dl))
#     169         finally: dl.num_workers = w
#     170         if detach: x,y = to_detach(x,cpu=cpu),to_detach(y,cpu=cpu)
#
# c:\users\asish\appdata\local\programs\python\python37\lib\site-packages\fastai\basic_data.py in __iter__(self)
#      73     def __iter__(self):
#      74         "Process and returns items from `DataLoader`."
# ---> 75         for b in self.dl: yield self.proc_batch(b)
#      76
#      77     @classmethod
#
# c:\users\asish\appdata\local\programs\python\python37\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     344     def __next__(self):
#     345         index = self._next_index()  # may raise StopIteration
# --> 346         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     347         if self._pin_memory:
#     348             data = _utils.pin_memory.pin_memory(data)
#
# c:\users\asish\appdata\local\programs\python\python37\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# c:\users\asish\appdata\local\programs\python\python37\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# c:\users\asish\appdata\local\programs\python\python37\lib\site-packages\fastai\data_block.py in __getitem__(self, idxs)
#     652             else:                 x,y = self.item   ,0
#     653             if self.tfms or self.tfmargs:
# --> 654                 x = x.apply_tfms(self.tfms, **self.tfmargs)
#     655             if hasattr(self, 'tfms_y') and self.tfm_y and self.item is None:
#     656                 y = y.apply_tfms(self.tfms_y, **{**self.tfmargs_y, 'do_resolve':False})
#
# AttributeError: 'str' object has no attribute 'apply_tfms'
